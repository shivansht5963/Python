# %% [markdown]
# <a href="https://colab.research.google.com/github/shivansht5963/Python/blob/main/RNN_from_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class DataReader:
    def __init__(self, file_path, seq_length):
        with open(file_path, 'r', encoding='utf-8') as f:
            self.data = f.read()
        self.chars = sorted(list(set(self.data)))
        self.vocab_size = len(self.chars)
        self.char_to_ix = {ch: i for i, ch in enumerate(self.chars)}
        self.ix_to_char = {i: ch for i, ch in enumerate(self.chars)}
        self.seq_length = seq_length
        self.pointer = 0

    def next_batch(self):
        if self.pointer + self.seq_length + 1 >= len(self.data):
            self.pointer = 0
        inputs = [self.char_to_ix[ch] for ch in self.data[self.pointer:self.pointer + self.seq_length]]
        targets = [self.char_to_ix[ch] for ch in self.data[self.pointer + 1:self.pointer + self.seq_length + 1]]
        self.pointer += self.seq_length
        return inputs, targets

# %%
import numpy as np

class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        self.init_weights()

    def init_weights(self):
        self.Wxh = np.random.randn(self.hidden_size, self.vocab_size) * 0.01
        self.Whh = np.random.randn(self.hidden_size, self.hidden_size) * 0.01
        self.Why = np.random.randn(self.vocab_size, self.hidden_size) * 0.01
        self.bh = np.zeros((self.hidden_size, 1))
        self.by = np.zeros((self.vocab_size, 1))

    def softmax(self, x):
        e_x = np.exp(x - np.max(x))
        return e_x / np.sum(e_x)

    def loss_fun(self, inputs, targets, hprev):
        xs, hs, ys, ps = {}, {}, {}, {}
        hs[-1] = np.copy(hprev)
        loss = 0

        # Forward pass
        for t in range(len(inputs)):
            xs[t] = np.zeros((self.vocab_size, 1))
            xs[t][inputs[t]] = 1
            hs[t] = np.tanh(np.dot(self.Wxh, xs[t]) + np.dot(self.Whh, hs[t - 1]) + self.bh)
            ys[t] = np.dot(self.Why, hs[t]) + self.by
            ps[t] = self.softmax(ys[t])
            loss += -np.log(ps[t][targets[t], 0])

        # Backward pass
        dWxh, dWhh, dWhy = np.zeros_like(self.Wxh), np.zeros_like(self.Whh), np.zeros_like(self.Why)
        dbh, dby = np.zeros_like(self.bh), np.zeros_like(self.by)
        dhnext = np.zeros_like(hs[0])
        for t in reversed(range(len(inputs))):
            dy = np.copy(ps[t])
            dy[targets[t]] -= 1
            dWhy += np.dot(dy, hs[t].T)
            dby += dy
            dh = np.dot(self.Why.T, dy) + dhnext
            dhraw = (1 - hs[t] * hs[t]) * dh
            dbh += dhraw
            dWxh += np.dot(dhraw, xs[t].T)
            dWhh += np.dot(dhraw, hs[t - 1].T)
            dhnext = np.dot(self.Whh.T, dhraw)

        for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
            np.clip(dparam, -5, 5, out=dparam)

        return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs) - 1]

    def sample(self, h, seed_ix, n):
        x = np.zeros((self.vocab_size, 1))
        x[seed_ix] = 1
        ixes = []
        for t in range(n):
            h = np.tanh(np.dot(self.Wxh, x) + np.dot(self.Whh, h) + self.bh)
            y = np.dot(self.Why, h) + self.by
            p = self.softmax(y)
            ix = np.random.choice(range(self.vocab_size), p=p.ravel())
            x = np.zeros((self.vocab_size, 1))
            x[ix] = 1
            ixes.append(ix)
        return ixes
    def train(self, data_reader, iterations=10000):
        hprev = np.zeros((self.hidden_size, 1))
        for i in range(iterations):
            inputs, targets = data_reader.next_batch()
            loss, dWxh, dWhh, dWhy, dbh, dby, hprev = self.loss_fun(inputs, targets, hprev)

            # Update parameters
            for param, dparam in zip([self.Wxh, self.Whh, self.Why, self.bh, self.by],
                                     [dWxh, dWhh, dWhy, dbh, dby]):
                param -= self.learning_rate * dparam

            if i % 250 == 0:
                sample_ix = self.sample(hprev, inputs[0], 100)
                generated = ''.join(data_reader.ix_to_char[ix] for ix in sample_ix)
                input_text = ''.join(data_reader.ix_to_char[ix] for ix in inputs)

                print(f"\nIteration: {i}, Loss: {loss:.4f}")
                print(f"Input: {input_text}")
                print(f"Generated Text: {generated}")

# %%
seq_length = 25
data_reader = DataReader("interstellar_summary_condensed.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size, seq_length=seq_length, learning_rate=1e-3)
rnn.train(data_reader)
# Out:
# Iteration: 0, Loss: 95.7139
# Input: Interstellar is a 2014 sc
# Generated Text: liiqjan.B4HIqecSNk2 qviJijMdhovhJ2m,BceoMbtgSj0ToM2AigI,heTqkSp0IqsA4jnIwArqEgqkfHgh4uBtA2eJbf1mM,ks
#
# Iteration: 250, Loss: 90.5309
# Input: n future, Earth faces bli
# Generated Text: V gdDgibjahJVBgjkCboBTdid urb.id 4E tiuotlpMtqdnM1no NhucHi.cM1jelbgg.mxSjjMhTSMdE bnm,l4hTmBDwfraxn
#
# Iteration: 500, Loss: 84.3825
# Input: ssion with scientists Bra
# Generated Text:  y u ct. gqniJIxvdoonesg o,xpa D IIb 0INN eBjBe0uTdJirvoSnrortaHN l2y2ryysC0Hef4JAwtHRhrloCC .rIgiBR
#
# Iteration: 750, Loss: 71.8979
# Input: on across time with his d
# Generated Text: 1hdcAft leosmrirRaesRe iiSoramt stfnBeia uuisV naso,iieRTawt,rrs srMtt esiHus r0ta, epe nnhAenwsaapa
#
# Iteration: 1000, Loss: 72.0691
# Input: ience fiction drama direc
# Generated Text:  t ocie tt n ufideeowithtaeray0ibe pDi nthfo  eviahv  a Csstit slra Intoesats giips a ctfeEHgautiont
#
# Iteration: 1250, Loss: 77.9675
# Input: ght and famine. A group o
# Generated Text: yhcds.maioeace.ufhitsssiidnn  rntadointl rotb.qTuvt1 mnrMoNdayrepghCeefoynns n vAfemmJsdmc alcwe ego
#
# Iteration: 1500, Loss: 89.4070
# Input: nd, Romilly, and Doyle. T
# Generated Text: aRtmisfAd npa o mwo mrw hcetr on tmpecDad efpatih.4 ewslm rtaamnrec hemfdne eeai,acyr ylaaet olcorM
#
# Iteration: 1750, Loss: 81.6228
# Input: aughter Murph, who solves
# Generated Text: oynear  l 2ss sC,unnpiniym.Ii.cpl rcucwwo keba trtigd ehfad e de,asygfd tlddiaeo sscsrhfe,l r fnccat
#
# Iteration: 2000, Loss: 80.4366
# Input: ted by Christopher Nolan.
# Generated Text: Eacdemrjpporidnhirveia ofesrwot  bneo  pteaerhasnMnadhdnio p diCatnni o lhesntni islAeM oEoean fnitc
#
# Iteration: 2250, Loss: 72.6719
# Input: f astronauts travels thro
# Generated Text: r,stAssortrihfseaia fa hsolt ifSpCafCrta b .i aeoragrRB hrves sarfatgm Jaasaafi e D ga aiedoyeacCt d
#
# Iteration: 2500, Loss: 77.3942
# Input: hey explore planets affec
# Generated Text: hnvAm.STusrrhh ee ooeoaosntnlny lraeeC, iefwwiuvlan uaaingli J4l s oddfoor e sropxth2iiyn nsaitehu b
#
# Iteration: 2750, Loss: 80.7900
# Input:  the gravity equation. Th
# Generated Text: cNiei esero sldsna eo  tnnH iatAkTmi a,n4gEen e. nshrrw,a4,aeiel. h dhr atmy cD sen mymeeeiiVdets id
#
# Iteration: 3000, Loss: 81.6018
# Input:  It stars Matthew McConau
# Generated Text: mbsuse a hnee eacrdca ut , io aqsaynnaRgtn ntdth aacc amneCrT hedni0clp yia lddeempidifisecoriricM p
#
# Iteration: 3250, Loss: 74.3779
# Input: ugh a wormhole near Satur
# Generated Text: e mvblnedgoiietnpMnuecrus g  varrsh mcoqlHitsaoa w ectunSwp hseoi n an he es ao aarrtarr a srcsC ste
#
# Iteration: 3500, Loss: 69.4685
# Input: ted by time dilation and
# Generated Text: to eo.e 2net cpqoAh so tut henasvsxasH e nsalnaotno ucnocttmnothoch hro goeac Mne fmg fniooeonoarAtt
#
# Iteration: 3750, Loss: 71.2546
# Input: e film received positive
# Generated Text: woponaieiusie r,or sMrgCret dfaxhanrsM ateaf ufrdp ihsie w awnt. tf crniT bn vh .st am imer wreed ps
#
# Iteration: 4000, Loss: 78.9097
# Input: ghey, Anne Hathaway, Jess
# Generated Text: s eee Ci kasc AtiskCsoef pie..htnin ig mheei ilwieieri2iatan faesIpesmreEaoraitsiat,a nie oct atusu
#
# Iteration: 4250, Loss: 69.0592
# Input: n seeking a new home for
# Generated Text: plneha dja ns faCfareh en whd buMdyi t dEtwoece, bpfnmets 2Tona A pti tbb aabarg gf xilicvsd kopyota
#
# Iteration: 4500, Loss: 69.0123
# Input: face personal sacrifices.
# Generated Text:  Nha a nyhee hcsixnoeJ.h aamres ae rii sieet.w eecre al.r aralrhafs d Dhr arbreosyg asTyrorbh qrJ sn
#
# Iteration: 4750, Loss: 67.5009
# Input: reviews and won an Academ
# Generated Text:  arcctiowaa ahsa t nion yodr pfeuJw attyfe rsorh phsas fhJes r m cni. fiam p mihias f4ee JmMrcs wocc
#
# Iteration: 5000, Loss: 63.7374
# Input: ica Chastain, and Michael
# Generated Text: Aar nyy Ainm4c aho DrvmiuesessecT aaTMB acereos Mexde tnte SvcuitshaemelNefs vyiecat Centhn s gtrvaf
#
# Iteration: 5250, Loss: 65.3461
# Input: mankind. Cooper, a former
# Generated Text: trEvnChepv t ohsr ahdoso fos fsttow eunma totatm Cen anqloNmilosae.e woshipee anMowaee a gs foss Coa
#
# Iteration: 5500, Loss: 62.6635
# Input:  Cooper discovers a tesse
# Generated Text: AansekBc ianc wisely gen Boni pin temioMrtdse tinhanr fhrevrnten bspe wanedlw .nt ggt iole Chn u,ud
#
# Iteration: 5750, Loss: 69.9162
# Input: y Award for Best Visual E
# Generated Text: sp oa ayi ft s tarver aims f ver tua d .hsaseoufen blnied dndsas dxfpa. tora d aem, fesu qlctpvr qel
#
# Iteration: 6000, Loss: 63.7338
# Input:  Caine. Set in a dystopia
# Generated Text: eey pe1atehd AeAecA bossc fn mocorid ar pisew tlfs aibee than aimc, Micec rtoffekecseveen aniauqorn
#
# Iteration: 6250, Loss: 71.8323
# Input:  NASA pilot, joins the mi
# Generated Text: ard ter Sic the arc,cs womc faol aswecmoo,e woa, aos foc oca a Ins bas aypacvarCaotlrialgeB MDmtol a
#
# Iteration: 6500, Loss: 71.5226
# Input: ract enabling communicati
# Generated Text: he dhesia, fon Aith avces,rhwyme sitee hesenvormeasinme Honithandy Cohis nimee Mos vhAreclecpfde top
#
# Iteration: 6750, Loss: 76.4610
# Input: Interstellar is a 2014 sc
# Generated Text: s Mipn atIw rBanu, B0w aeon nlate. D Vrt orn Moce Sim a aoIe disos d rh E tantet Blgorin lotemve Ied
#
# Iteration: 7000, Loss: 64.7006
# Input: n future, Earth faces bli
# Generated Text: er Hatas Boa En ioc ncterd. Iard And aSg toot an lon Nhstrhe segpa ayd gnpett por, ramea bius suerte
#
# Iteration: 7250, Loss: 56.4891
# Input: ssion with scientists Bra
# Generated Text: diand y an. Iod araenl alaartion forine Alas elan Nomarmh Cnrbs moomevtin,stersmr aca finisv mits s
#
# Iteration: 7500, Loss: 53.8994
# Input: on across time with his d
# Generated Text: talturetr onme finus iin g firr pisehw poone dian.edint Tise, Dhen Aor.rmeed Torercisas tocuonse g m
#
# Iteration: 7750, Loss: 53.5710
# Input: ience fiction drama direc
# Generated Text: clor amin tamler an. Vime , ana fe aomiules atwisn Jh, tokau. Eracm mhoeien. Mnetr Bommr Thatavmion
#
# Iteration: 8000, Loss: 58.5593
# Input: ght and famine. A group o
# Generated Text: iic. teA fineen T4thls fanthron errysada ferpert fac aucerp Mne pginkit d feA. matee, b 0obtir thl f
#
# Iteration: 8250, Loss: 56.1783
# Input: nd, Romilly, and Doyle. T
# Generated Text: s sie theine, Dad fargchelris aytbacacfofeiste d D ter lna. Ain en Aewsesta Torg sjhowmh ela jh onar
#
# Iteration: 8500, Loss: 61.9469
# Input: aughter Murph, who solves
# Generated Text: ne Aacima tisetd soMpeosienp4a. by and aemticn Mlan, vlarion eiters poruol. whtl aich s fonev, foren
#
# Iteration: 8750, Loss: 54.7100
# Input: ted by Christopher Nolan.
# Generated Text: ionthane femB Cntroniry souiars Siy teg en cotey ava Ciin s aek thogte s anvt foJtorhes aote nasd Ch
#
# Iteration: 9000, Loss: 58.5789
# Input: f astronauts travels thro
# Generated Text: elthewpeupertorrerict andslertien d alanuew anterohictron, tetverrome thor rhet and Ry rocey ew Th t
#
# Iteration: 9250, Loss: 59.7523
# Input: hey explore planets affec
# Generated Text: er angervislicel rrand Titr Va Ceticm wotisilh fior parehs an Brel Aot oneifcinewunc wivy aeb giml k
#
# Iteration: 9500, Loss: 55.9825
# Input:  the gravity equation. Th
# Generated Text: poon, fatevon, tomivuin, Snifith. SVa discisat tcaepe fioa h phe pal dhaveduRimg fce mitl dv tamer e
#
# Iteration: 9750, Loss: 57.1987
# Input:  It stars Matthew McConau
# Generated Text: rtacionica tistayit, Ricos er datiratd fian. wat wan wofbos intt pisurs wos an McJmunth fA tomile, D
